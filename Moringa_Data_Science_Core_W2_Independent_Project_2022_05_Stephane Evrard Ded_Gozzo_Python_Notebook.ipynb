# %% [markdown]
# ## ***I-Defining the Question***

# %% [markdown]
# ***1-Specifying the question***

# %%
# Research question # Predict which individuals are most likely to have or use a bank account.

# Provide an indication of the state of the financial inclusion in kenya, Rwanda, Tanzania and Uganda

# Provide insights into some of the key demographic factors that might drive individual's financial outcomes.

# %% [markdown]
# ***2-Defining the Metric for Success***

# %%
# The following areas will be covered to successfully achieve the objectives of the project:

# Exploratory Data Analysis
# Univariate, Bivariate and Multivariate analysis
# Visualizations

# %% [markdown]
# ***3-Understanding the context***

# %%
# Variable Definitions / Data Dictionary: http://bit.ly/VariableDefinitions 

# Financial Inclusion remains one of the main obstacles to economic and human development in Africa.
# For example, across Kenya, Rwanda, Tanzania, and Uganda only 9.1 million adults (or 13.9% of the adult population) have access to or use a commercial bank account.

# Traditionally, access to bank accounts has been regarded as an indicator of financial inclusion. 

# Despite the proliferation of mobile money in Africa and the growth of innovative fintech solutions, 
# banks still play a pivotal role in facilitating access to financial services. 
# Access to bank accounts enables households to save and facilitate payments while also helping businesses build up their credit-worthiness and 
# improve their access to other financial services. 
# Therefore, access to bank accounts is an essential contributor to long-term economic growth.

# %% [markdown]
# ***4-Recording the Experimental Design***

# %%
# To successfully conduct this project the following steps will be taken in order:

# Conduct Exploratory Data Analysis
# Univariate, Bivariate and Multivariate analysis
# Create Visualizations
# challenging the solution to find  if its the best for this particular scenario.

# %% [markdown]
# ***5-Data Relevance***

# %%
# The data provided fits the context of our study.
# It contains crucial variables that can be used for our prediction.
# The main dataset contains demographic information and what financial services are used by individuals across East Africa.
# This data was extracted from various Finscope surveys ranging from 2016 to 2018, and more information about these surveys can be found here:
# FinAccess Kenya 2018: https://fsdkenya.org/publication/finaccess2019/
# Finscope Rwanda 2016: http://www.statistics.gov.rw/publication/finscope-rwanda-2016
# Finscope Tanzania 2017:  http://www.fsdt.or.tz/finscope/
# Finscope Uganda 2018: http://fsduganda.or.ug/finscope-2018-survey-report/ 
# Dataset Files:

# Variable Definitions: http://bit.ly/VariableDefinitions 
# Dataset: http://bit.ly/FinancialDataset

# %% [markdown]
# # ***II-Reading the dataset***

# %% [markdown]
# ## ***1- Importing Libraries***

# %%
# import pandas

import pandas as pd

# import numpy

import numpy as np

# import datetime

import datetime

# import matplotlib

import matplotlib as plt

# import seaborn

import seaborn as sns

# import matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline

# import pandas profiling

# import pandas_profiling 
# from pandas_profiling import ProfileReport

# immport scipy

import scipy.stats as stats

# %% [markdown]
# ## ***2-Loading Datasets***

# %%
# Load Financial Dataset 

df = pd.read_csv('http://bit.ly/FinancialDataset')

# %%
# Load column name definitions

vdef = pd.read_csv('http://bit.ly/VariableDefinitions')

# %% [markdown]
# ## ***3-Preview Datasets***

# %% [markdown]
# ***a-Vdef - Variable Definitions***

# %%
# viewing the 15  entries in the Variable definitions

vdef.head(15)
# Out:
#       Variable Definitions                                         Unnamed: 1
# 0                  country                         Country interviewee is in.
# 1                     year                           Year survey was done in.
# 2                 uniqueid             Unique identifier for each interviewee
# 3            location_type                     Type of location: Rural, Urban
# 4         cellphone_access  If interviewee has access to a cellphone: Yes, No
# 5           household_size               Number of people living in one house
# 6        age_of_respondent                         The age of the interviewee
# 7     gender_of_respondent                Gender of interviewee: Male, Female
# 8   relationship_with_head  The interviewee’s relationship with the head o...
# 9           marital_status  The martial status of the interviewee: Married...
# 10         education_level  Highest level of education: No formal educatio...
# ...

# %% [markdown]
# ***b- df - Financial Dataset***

# %%
# viewing the first five entries in the dataset

df.head()
# Out:
#   country  year    uniqueid Has a Bank account Type of Location  \
# 0   Kenya  2018  uniqueid_1                Yes            Rural
# 1   Kenya  2018  uniqueid_2                 No            Rural
# 2   Kenya  2018  uniqueid_3                Yes            Urban
# 3   Kenya  2018  uniqueid_4                 No            Rural
# 4   Kenya  2018  uniqueid_5                 No            Urban
#
#   Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 0               Yes             3.0            24.0               Female
# 1                No             5.0            70.0               Female
# 2               Yes             5.0            26.0                 Male
# 3               Yes             5.0            34.0               Female
# 4                No             8.0            26.0                 Male
#
#   The relathip with head           marital_status  \
# 0                 Spouse  Married/Living together
# ...

# %%
# viewing the last five entries in the dataset

df.tail()
# Out:
#       country  year       uniqueid Has a Bank account Type of Location  \
# 23519  Uganda  2018  uniqueid_2113                 No            Rural
# 23520  Uganda  2018  uniqueid_2114                 No            Rural
# 23521  Uganda  2018  uniqueid_2115                 No            Rural
# 23522  Uganda  2018  uniqueid_2116                 No            Urban
# 23523  Uganda  2018  uniqueid_2117                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 23519               Yes             4.0            48.0               Female
# 23520               Yes             2.0            27.0               Female
# 23521               Yes             5.0            27.0               Female
# 23522               Yes             7.0            30.0               Female
# 23523               Yes            10.0            20.0                 Male
#
#       The relathip with head        marital_status  Level of Educuation  \
# ...

# %%
# Viewing of 10 samples

df.sample(10)
# Out:
#         country  year       uniqueid Has a Bank account Type of Location  \
# 17107  Tanzania  2017  uniqueid_2305                 No            Urban
# 41        Kenya  2018    uniqueid_42                 No            Urban
# 1319      Kenya  2018  uniqueid_1320                 No            Urban
# 14372    Rwanda  2016  uniqueid_8305                Yes            Urban
# 13440    Rwanda  2016  uniqueid_7373                 No            Rural
# 22856    Uganda  2018  uniqueid_1434                 No            Rural
# 8219     Rwanda  2016  uniqueid_2152                 No            Urban
# 9768     Rwanda  2016  uniqueid_3701                Yes            Rural
# 18617  Tanzania  2017  uniqueid_3815                Yes            Rural
# 4168      Kenya  2018  uniqueid_4169                 No            Rural
#
#       Cell Phone Access  household_size  Respondent Age gender_of_respondent  \
# 17107               Yes             2.0            42.0                 Male
# ...

# %% [markdown]
# ***4-Learning more about the Data***

# %%
# checking the dataset shape

# df.shape

print('This dataset has ' + str(df.shape[0]) + ' rows and ' + str(df.shape[1]) + ' columns' )
# Out:
# This dataset has 23524 rows and 13 columns

# %%
# checking the columns
df.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'Has a Bank account', 'Type of Location',
#        'Cell Phone Access', 'household_size', 'Respondent Age',
#        'gender_of_respondent', 'The relathip with head', 'marital_status',
#        'Level of Educuation', 'Type of Job'],
#       dtype='object')

# %%
# Checking whether each column has an appropriate datatype

df.dtypes
# Out:
# country                    object
# year                        int64
# uniqueid                   object
# Has a Bank account         object
# Type of Location           object
# Cell Phone Access          object
# household_size            float64
# Respondent Age            float64
# gender_of_respondent       object
# The relathip with head     object
# marital_status             object
# Level of Educuation        object
# Type of Job                object
# dtype: object

# %%
# checking the dataset information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23510 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   Has a Bank account      23488 non-null  object
#  4   Type of Location        23509 non-null  object
#  5   Cell Phone Access       23513 non-null  object
#  6   household_size          23496 non-null  float64
#  7   Respondent Age          23490 non-null  float64
#  8   gender_of_respondent    23490 non-null  object
#  9   The relathip with head  23520 non-null  object
#  10  marital_status          23492 non-null  object
#  11  Level of Educuation     23495 non-null  object
#  12  Type of Job             23494 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 2.3+ MB

# %%
# Descrpition of the dataset

df.describe()
# Out:
#                year  household_size  Respondent Age
# count  23524.000000    23496.000000    23490.000000
# mean    2016.979000        3.681818       38.804300
# std        0.899669        2.279933       16.519996
# min     2016.000000        0.000000       16.000000
# 25%     2016.000000        2.000000       26.000000
# 50%     2017.000000        3.000000       35.000000
# 75%     2018.000000        5.000000       49.000000
# max     2056.000000       21.000000      100.000000

# %% [markdown]
# # ***III- Cleaning the Data***

# %% [markdown]
# ***1- Standardizing Column names***

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ','_').str.replace('(', '').str.replace(')', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ***2-Identifying outliers***

# %%
# checking for outliers on variable household_size

plt.title("year boxplot" , color = 'blue')
sns.boxplot(df['year'])
plt.show()
# the boxplot shows presence of outliers
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In reference to the above box plot, this study was conducted between 2016 and 2018, any value above 2018 is an outlier. hence we shall drop it

# %%
# checking for outliers on variable household_size
plt.title("Household number boxplot", color = 'blue')
sns.boxplot(df['household_size'])
plt.show()

# the boxplot shows presence of outliers
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# In reference to the above box plot and the maximum: "Q3 +1.5*IQR" formula, values above 9 are outliers. Hence we shall drop them

# %%
# checking for outliers on variable respondent age
plt.title("respondent_age_boxplot", color = 'blue')
sns.boxplot(df['respondent_age'])
plt.show()

# The boxplot shows the presence of outliers
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# n reference to the above box plot and the maximum: "Q3 +1.5*IQR" formula, values above 82 are outliers. Hence we shall drop them

# %% [markdown]
# ***3-Dropping Outliers***

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)

IQR = Q3 - Q1
IQR
df = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape

# Printing the shape of the new dataset
df.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
# (22903, 13)

# %% [markdown]
# ***4-Tidying the Datasets***

# %%
# Dropping columns we do not need for this analysis

df = df.drop(['uniqueid'], axis = 1)

# %% [markdown]
# ***5-Handling messy columns names***

# %%
# checking the column names
# Renaming the columns: rectifying typos

df.columns
# Out:
# Index(['country', 'year', 'has_a_bank_account', 'type_of_location',
#        'cell_phone_access', 'household_size', 'respondent_age',
#        'gender_of_respondent', 'the_relathip_with_head', 'marital_status',
#        'level_of_educuation', 'type_of_job'],
#       dtype='object')

# %%
df.rename(columns={'the_relathip_with_head':'the_relation_with_head'}, inplace=True)

# %%
df.rename(columns={'level_of_educuation':'level_of_education'}, inplace=True)

# %%
# confirming the columns names

df.columns
# Out:
# Index(['country', 'year', 'has_a_bank_account', 'type_of_location',
#        'cell_phone_access', 'household_size', 'respondent_age',
#        'gender_of_respondent', 'the_relation_with_head', 'marital_status',
#        'level_of_education', 'type_of_job'],
#       dtype='object')

# %% [markdown]
# ***6-Missing values***

# %%
# Missing values

# checking the number of missing values by column

df.isnull().sum()
# Out:
# country                   14
# year                       0
# has_a_bank_account        36
# type_of_location          15
# cell_phone_access         11
# household_size            27
# respondent_age            33
# gender_of_respondent      33
# the_relation_with_head     4
# marital_status            31
# level_of_education        29
# type_of_job               30
# dtype: int64

# %%
# Dropping all null values in our dataframe
df.dropna(inplace = True)

# %%
# confriming there are no missing values

df.isnull().sum()
# Out:
# country                   0
# year                      0
# has_a_bank_account        0
# type_of_location          0
# cell_phone_access         0
# household_size            0
# respondent_age            0
# gender_of_respondent      0
# the_relation_with_head    0
# marital_status            0
# level_of_education        0
# type_of_job               0
# dtype: int64

# %%
# Dropping duplicate values
df.drop_duplicates()
df.shape
# Out:
# (22725, 12)

# %%
# Dropping Unnecessary columns

df.drop(['the_relation_with_head'], axis = 1, inplace = True) 
df.head(5)
# Out:
#   country  year has_a_bank_account type_of_location cell_phone_access  \
# 0   Kenya  2018                Yes            Rural               Yes
# 1   Kenya  2018                 No            Rural                No
# 2   Kenya  2018                Yes            Urban               Yes
# 3   Kenya  2018                 No            Rural               Yes
# 4   Kenya  2018                 No            Urban                No
#
#    household_size  respondent_age gender_of_respondent  \
# 0             3.0            24.0               Female
# 1             5.0            70.0               Female
# 2             5.0            26.0                 Male
# 3             5.0            34.0               Female
# 4             8.0            26.0                 Male
#
#             marital_status               level_of_education  \
# 0  Married/Living together              Secondary education
# 1                  Widowed              No formal education
# ...

# %%
df.columns
# Out:
# Index(['country', 'year', 'has_a_bank_account', 'type_of_location',
#        'cell_phone_access', 'household_size', 'respondent_age',
#        'gender_of_respondent', 'marital_status', 'level_of_education',
#        'type_of_job'],
#       dtype='object')

# %% [markdown]
# ***7-Anomalies***

# %%
# From the profile report we saw that the year column had anomalies (2029,2059,2039)

# the data description of the year column (Year survey was done in) only included(2016,2017,2018)

# %%
# Removing the anomalies on the year column

indexnames = df[df['year'] > 2018].index

df.drop(indexnames, inplace = True)

# %%
# checking that there are no anomalies in the year column

df.year.unique()
# Out:
# array([2018, 2016, 2017])

# %% [markdown]
# ## ***IV- Exploratory Data Analysis***

# %% [markdown]
# ***1-Measures of Central Tendency***

# %%
# MODE

# %%
# mode of the country


df.country.mode()

# most occuring country is Rwanda
# Out:
# 0    Rwanda
# dtype: object

# %%
# mode of the year

df.year.mode()

# most occuring year is 2016
# Out:
# 0    2016
# dtype: int64

# %%
# People with bank account or not

df.has_a_bank_account.mode()

# most occuring is No
# Out:
# 0    No
# dtype: object

# %%
# the type location of people

df.type_of_location.mode()

# most occuring location is Rural
# Out:
# 0    Rural
# dtype: object

# %%
# People with cell phone access

df.cell_phone_access.mode()

# most occuring Yes
# Out:
# 0    Yes
# dtype: object

# %%
# mode of the respondent household_size

df.household_size.mode()

# most occuring household size was 2 members only
# Out:
# 0    2.0
# dtype: float64

# %%
# mode of the respondent_age

df.respondent_age.mode()

# most occuring age is 30
# Out:
# 0    30.0
# dtype: float64

# %%
# mode of gender respondent

df.gender_of_respondent.mode()

# most occuring is Female
# Out:
# 0    Female
# dtype: object

# %%
# mode of marital status

df.marital_status.mode()

# most occuring is Married/Living together
# Out:
# 0    Married/Living together
# dtype: object

# %%
# mode of education level 

df.level_of_education.mode()

# most occuring is Primary education
# Out:
# 0    Primary education
# dtype: object

# %%
# mode of job type

df.type_of_job.mode()

# most occuring is Self employed
# Out:
# 0    Self employed
# dtype: object

# %%
modedf = pd.DataFrame()
modedf

data = {'Criteria': ['country',
 'year',
 'has_a_bank_account',
 'type_of_location',
 'cell_phone_access',
 'household_size',
 'respondent_age',
 'gender_of_respondent',
 'the_relationship_with_head',
 'marital_status',
 'level_of_education',
 'type_of_job'], 'Majority of the respondents': ['Come from Rwanda', 'Responded in 2016', 'Dont have bank accounts', 'Come from Rural areas', 'Have Celphone Access', 'Come from 2 people households', '30 years old', 'Are Female', 'Are the head of House hold', 'Are Married or living together', 'Have primary level education','Are self employed']} 
modedf =pd.DataFrame(data)
modedf
# Out:
#                       Criteria     Majority of the respondents
# 0                      country                Come from Rwanda
# 1                         year               Responded in 2016
# 2           has_a_bank_account         Dont have bank accounts
# 3             type_of_location           Come from Rural areas
# 4            cell_phone_access            Have Celphone Access
# 5               household_size   Come from 2 people households
# 6               respondent_age                    30 years old
# 7         gender_of_respondent                      Are Female
# 8   the_relationship_with_head      Are the head of House hold
# 9               marital_status  Are Married or living together
# 10          level_of_education    Have primary level education
# 11                 type_of_job               Are self employed

# %%
# MEDIAN

# %%
# median of the respondent household_size

df.household_size.median()

# arranging the data in ascending/descending order, the middle observation for the household size is 3
# Out:
# 3.0

# %%
# median of the respondent_age

df.respondent_age.median()

# arranging the data in ascending/descending order, the middle age was 35
# Out:
# 35.0

# %%
# MEAN

# %%
# Mean of the respondent household_size

df.household_size.mean()

# average household size is 3
# Out:
# 3.57984598459846

# %%
# Mean of the respondent respondent_age

df.respondent_age.mean()

# average age of the interviewees was 38
# Out:
# 38.34798679867987

# %% [markdown]
# ***2-Measures of Dispersion/Variability/Spread***

# %%
# RANGE


# difference between lowest and highest value
# find maximum value 
# find minimum value
# range = max - min

# %%
# Range of the household_size

hMax = df.household_size.max()
print(hMax)

hMin = df.household_size.min()
print(hMin)

hRange = hMax - hMin
print(hRange)

print('The range of the household size is ' + str(hRange))
# Out:
# 9.0
# 0.0
# 9.0
# The range of the household size is 9.0

# %%
# Range of the respondent_age

aMax = df.respondent_age.max()
print(aMax)

aMin = df.respondent_age.min()
print(aMin)

aRange = aMax - aMin
print(aRange)

print('The range of the respondent age is ' + str(aRange))
# Out:
# 83.0
# 16.0
# 67.0
# The range of the respondent age is 67.0

# %%
# QUANTILES

# Quartiles are values that divide your data into quarters when data is sorted in an ascending order.

# There are three quartile values. 

# Q1: First quartile is the 25 percentile. 
# Q2: Second quartile is the 50 percentile...also...median of the data
# Q3: Third quartile is the 75 percentile. 


# THE INTERQUARTILE RANGE ...also ..IQR

# IQR = Q3 -Q1

# %%
# Quantiles of the household_size

df['household_size'].quantile([0.25,0.5,0.75])
# Out:
# 0.25    2.0
# 0.50    3.0
# 0.75    5.0
# Name: household_size, dtype: float64

# %%
# Quantiles of the respondent_age

df["respondent_age"].quantile([0.25,0.5,0.75])
# Out:
# 0.25    26.0
# 0.50    35.0
# 0.75    48.0
# Name: respondent_age, dtype: float64

# %%
# STANDARD DEVIATION

# Average distance between each obseravtion from the mean. 
# I.e., how data is spread out from mean. 
# A low std dev indicates that the data points tend to be close to the mean of the data set, 
# A high std dev indicates that the data points are spread out over a wider range of values.

# %%
# Standard Deviation of the household_size

df.household_size.std()


# 2 is a low std dev hence the data points are close to the mean (3.57) of the data set
# Out:
# 2.080542136724138

# %%
# Standard Deviation of the respondent_age

df.respondent_age.std()


# 15.8 is a high std dev showing that the data points are spread out over a wide range of values
# Out:
# 15.806141256107674

# %%
# VARIANCE 

# square of average distance between each observation and mean. 
# I.e. square of standard deviation. 
# It is a measure of how dispersed or spread out the set is, 

# If a data set has a variance of zero, then every member of it is the same. 
# If the variance is high, especially as a ratio to the mean, then the data have some very large dis-similarities amongst its members.

# %%
# Variance of the household_size

df.var()

# var of 4.32 is a small variance compared to the mean of 3.57 hence the dataset does have few dis-similarities amongst its members
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# year                0.716335
# household_size      4.328656
# respondent_age    249.834101
# dtype: float64

# %%
# Variance of the respondent_age

df.respondent_age.var()

# var of 249.83 is very large compared to the mean of 38.34. This indicates that the age distribution have some very large dis-similarities.
# Out:
# 249.83410140802906

# %%
# SKEWNESS 

# A measure of the asymmetry of the probability distribution of a real-valued random variable about its mean. 
# In a perfect normal distribution, the tails on either side of the curve are exact mirror images of each other.
# A negative value means the distribution is negatively skewed.....or...skewed to the left
# A positive value means the distribution is positively skewed.....or...skewed to the right

# %%
# Skewness of the household_size

df.skew()

# The household size distribution is skewed to the right since its skewness is a positive value.
# This was also seen in the histogram above on visualizations: long right tail.
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# year              0.060351
# household_size    0.605875
# respondent_age    0.740214
# dtype: float64

# %%
# KURTOSIS 

# A measure of whether the data are heavy-tailed (profusion of outliers)
# or light-tailed (lack of outliers) relative to a normal distribution.
# If the kurtosis is close to 0, then a normal distribution is often assumed....These are called mesokurtic distributions.                        
# If the kurtosis is less than zero, then the distribution has light tails ......called a platykurtic distribution.  
# If the kurtosis is greater than zero, then the distribution has heavier tails .... called a leptokurtic distribution.

# %%
# Kurtosis of the dataset

df.kurt()

# The  kurtosis is less than zero hence the distribution has light tails ....This is called a  platykurtic distribution
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   This is separate from the ipykernel package so we can avoid doing imports until
# year             -1.601466
# household_size   -0.505578
# respondent_age   -0.237494
# dtype: float64

# %% [markdown]
# ## ***V- Univariate exploratory Analysis***

# %% [markdown]
# ***1-Univariate Charts***

# %%
df.columns
# Out:
# Index(['country', 'year', 'has_a_bank_account', 'type_of_location',
#        'cell_phone_access', 'household_size', 'respondent_age',
#        'gender_of_respondent', 'marital_status', 'level_of_education',
#        'type_of_job'],
#       dtype='object')

# %% [markdown]
# ***a-Countries***

# %%
# Respondent per country

country = df.groupby(['country']).country.value_counts()

#country.value_counts() to count country


country.plot.bar(title = 'Respondents per country')

# %% [markdown]
# Most of the respondents are Rwandan followed by Tanzania then Kenya. Least respondents are from Uganda.

# %% [markdown]
# ***b-Year***

# %%
year = df.groupby(['year']).year.value_counts()

year.plot.pie(title = 'Respondents per year',autopct='%1.1f%%')

# %% [markdown]
# Most respondents participated in 2016. Closely followed by 2018 and least in 2017

# %% [markdown]
# ***c-What percentage has bank accounts***

# %%
# A pie chart of the respondents who had/ had no bank account

# grouping the data to be plotted

account = df.has_a_bank_account.value_counts()
account

# accessing the data to plot

# labels
sizes= account.index
sizes

# values
data = account.values
data

# plotting the pie chart

plt.figure(figsize = (4,4), dpi = 100)
plt.pie(data, labels = sizes, autopct = '%1.1f%%', shadow = True, explode = (0.1,0), startangle = 60)
plt.axis('equal')
plt.title('A Pie Chart of respondents with and without a bank account', color = 'purple')
plt.show()


# the pie chart shows only a few respondents (14.2%) had a bank account 
# the majority (85.8%) did not have a bank account

# %% [markdown]
# ***Type of Location***

# %%
# A pie chart of the type of location

# grouping the data to be plotted

location = df.type_of_location.value_counts()
location

# accessing the data to plot

# labels
sizes= location.index
sizes

# values
data = location.values
data

# plotting the pie chart

plt.figure(figsize = (4,4), dpi = 80)
plt.pie(data, labels = sizes, autopct = '%1.1f%%', shadow = True, explode = (0.1,0), startangle = 60)
plt.axis('equal')
plt.title('A Pie Chart of Rural vs Urban Population', color = 'purple')
plt.show()


# the pie chart shows only a few respondents (39.2%) live in Urban Area 
# the majority (85.8%) is in Rural Area

# %% [markdown]
# Majority of the participants are from Rural areas

# %% [markdown]
# ***d-Percentage of population with cellphone access***

# %%
# A pie chart of population with cellphone access

# grouping the data to be plotted

cell_phone = df.cell_phone_access.value_counts()
cell_phone

# accessing the data to plot

# labels
sizes= cell_phone.index
sizes

# values
data = cell_phone.values
data

# plotting the pie chart

plt.figure(figsize = (4,4), dpi = 80)
plt.pie(data, labels = sizes, autopct = '%1.1f%%', shadow = True, explode = (0.1,0), startangle = 60)
plt.axis('equal')
plt.title('A Pie Chart of Percentage of population with cellphone access', color = 'purple')
plt.show()


# the pie chart shows only a few respondents (25.3%) has no access to cellphone 
# the majority (74.7%) has access to cellphone

# %% [markdown]
# Majority of the population do have cellphone access

# %% [markdown]
# ***e- Household size***

# %%
df['household_size'].plot(kind="hist")

# %% [markdown]
# ***f- Respondents age***

# %%
df['respondent_age'].plot(kind="hist")

# %% [markdown]
# ***g- Perecentage of gender of respondents***

# %%
# A pie chart of gender of respondents

# grouping the data to be plotted

gender_of_respondent = df.gender_of_respondent.value_counts()
gender_of_respondent

# accessing the data to plot

# labels
sizes= gender_of_respondent.index
sizes

# values
data = gender_of_respondent.values
data

# plotting the pie chart

plt.figure(figsize = (4,4), dpi = 80)
plt.pie(data, labels = sizes, autopct = '%1.1f%%', shadow = True, explode = (0,0.1), startangle = 60)
plt.axis('equal')
plt.title('A Pie Chart of Perecentage of gender of respondents', color = 'purple')
plt.show()


# the pie chart shows only a few respondents (41.0%) is male 
# the majority (59.0%) is female

# %% [markdown]
# Majority of the respondents are female

# %% [markdown]
# ***h-Role in the household***

# %% [markdown]
# Majority of the respondents were the head of their households

# %% [markdown]
# ***i- Marital Status***

# %%
# Marital status of respondents

marital_status = df.groupby(['marital_status']).marital_status.value_counts()
marital_status.plot.pie(title = 'Marital Status of our respondents',autopct='%1.1f%%')

# %% [markdown]
# Majority of our respondents are married

# %% [markdown]
# ***j- Level of education of our respondents***

# %%
# Level of education

level_of_education = df.groupby(['level_of_education']).level_of_education.value_counts()
level_of_education.plot.bar(title = 'Level of education of our respondents')

# %% [markdown]
# Majority of our population only have primary education

# %% [markdown]
# ***k-Type of jobs of our population***

# %%
#type of job

type_of_job = df.groupby(['type_of_job']).type_of_job.value_counts()
type_of_job.plot.bar(title = 'Type of jobs of our respondents')

# %% [markdown]
# Ranking of employment is:
#
# 1.  Self employment
# 2.  Informally employed
#
# 1.   Farming and fishing

# %% [markdown]
# ## ***VI- Bivariate exploratory Analysis***

# %% [markdown]
# ***1-Bivariate Charts***

# %% [markdown]
# ***a- Access to banking facilities***

# %%
df.groupby(['country','has_a_bank_account']).count()
df.groupby(['country','has_a_bank_account']).year.count()

#Plotting our bar graph 
df.groupby(['country','has_a_bank_account']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Comparison of access to banking facilities per country',fontsize=16)
plt.xlabel('country',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=12)

# %% [markdown]
# As seen in the graphical representation above, Kenya has the highest banked population that participated in the survey. Uganda is the least banked. However this may not be an accurate representation because there are more respondents from Rwanda than other regions

# %% [markdown]
# ***b-Distribution of respondents location per country***

# %%
df.groupby(['country','type_of_location']).count()
df.groupby(['country','type_of_location']).year.count()

#Plotting our bar graph 
df.groupby(['country','type_of_location']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Distribution of population per country (Rural/ Urban)',fontsize=16)
plt.xlabel('country',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=12)

# %% [markdown]
# Tanzania has the largest population from urban location that participated in the survey. It is likely that the survey was conducted in one of the capital cities. We must acknowledge thet this may cause for the data to be skewed in more access to banking in tannzania as compared to other regions.
#
# The rest of the countries have most of the population in rural areas. This is an accurate representation. According to real world data, The region has alot of arable lands and is are developing countries. so you expect that most of the population will be in rural areas

# %% [markdown]
# ***c- Cellphone Access per country***

# %%
# cellphone access 

df.groupby(['country','cell_phone_access']).count()
df.groupby(['country','cell_phone_access']).year.count()

#Plotting our bar graph 
df.groupby(['country','cell_phone_access']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Distribution of population with cellphone access per country',fontsize=16)
plt.xlabel('country',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=12)

# %% [markdown]
# This is an interesting graphical representation of access to mobile phones in the region. Clearly, mobile phone penetration is high in the region. This could be an opportunity for the banks to tap this market through disruptive fintech banking e.g m-pesa

# %% [markdown]
# ***d- level of educuation compared by country***

# %%
df.groupby(['country','level_of_education']).count()
df.groupby(['country','level_of_education']).year.count()

#Plotting our bar graph 
df.groupby(['country','level_of_education']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Level of education per country',fontsize=16)
plt.xlabel('country',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=12)

# %% [markdown]
# In all of the countries, majority of the population has atleast primary education. Very few people have vocational and tertiary education. Uganda has the least people with tertiary education. Tanzania has the most people with tertiary education. given that majority of the Tanzania dataset is urban, we could expect more tertiary educated people in Tanzania

# %% [markdown]
# ***e- Type of job by countries***

# %%
# Type of job by countries

df.groupby(['country','type_of_job']).count()
df.groupby(['country','type_of_job']).year.count()

#Plotting our bar graph 
df.groupby(['country','type_of_job']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Type of job per country',fontsize=16)
plt.xlabel('country',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=10)

# %% [markdown]
# Given the large arable lands in the region, we could expect that most of the population to work in the farming industry. However in Tanzania and Uganda, most of the population is self employed. We could attribute this with the location of the respondent - either urban or rural

# %% [markdown]
# ***f- Bank Account according to gender***

# %%
# Bank account according to gender

df.groupby(['has_a_bank_account','gender_of_respondent']).count()
df.groupby(['has_a_bank_account','gender_of_respondent']).year.count()

#Plotting our bar graph 
df.groupby(['has_a_bank_account','gender_of_respondent']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Bank Account relation to Gender',fontsize=16)
plt.xlabel('Has bank account',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=10)

# %% [markdown]
# Out of the population that is banked, more men than women are banked. Out of the population that is not banked, more women than men are not banked. Generally, more men than women are banked

# %% [markdown]
# ***g- Bank Account corelation to level of education***

# %%
df.groupby(['has_a_bank_account','level_of_education']).count()
df.groupby(['has_a_bank_account','level_of_education']).year.count()

#Plotting our bar graph 
df.groupby(['has_a_bank_account','level_of_education']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Bank Account related to level of education',fontsize=16)
plt.xlabel('Has bank account',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=10)

# %% [markdown]
# Majority of the population is not banked. As you can see above, the data does not tell us if there is any correlation. The columns of banked population seems to be a shrinked version of the none banked population

# %% [markdown]
# ***h- Access to banking relation to marital status***

# %%
#Plotting our bar graph 
df.groupby(['has_a_bank_account','marital_status']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Bank Account related to marital status',fontsize=16)
plt.xlabel('Has bank account',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=14)

# %% [markdown]
# Out of the banked population, the married population is most banked. However most of the married people do not have bank accounts. Least of the widdowed and divorced population is not banked

# %% [markdown]
# ***i- Access to bank accounts vs type of job***

# %%
#Plotting our bar graph 
df.groupby(['has_a_bank_account','type_of_job']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Bank Access in relation to type of job',fontsize=16)
plt.xlabel('Has bank account',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=14)

# %% [markdown]
# This chart shows most of the self employed individuals are not banked. however majority of the formally emloyed in the private sector are banked. which is expected. Bankers shoulf focus on getting the self employed, farmers and and informally employed to bank in order to achieve more inclusion in the region

# %% [markdown]
# ***j- Access to banking facilities in relation to Location of respondents***

# %%
#Plotting our bar graph 
df.groupby(['has_a_bank_account','type_of_location']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Access to banking facilities in relation to Location of respondents',fontsize=16)
plt.xlabel('Location',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=14)

# %% [markdown]
# This chart shows that access to banking facilities is equal in both urban and rural areas. Given the previous charts, it makes sense that the focus should be to make banking more inclusive for the rural residents in order to achieve more inclusion

# %% [markdown]
# ***k- Location of residents in relation to level of education***

# %%
#Plotting our bar graph 
df.groupby(['type_of_location','level_of_education']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Location of residents in relation to level of education',fontsize=16)
plt.xlabel('Location',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=14)

# %% [markdown]
# Access to education seems to be equal in both urban and rural areas. The descripancy in the graph is because of a greater population being from rural areas

# %% [markdown]
# ***l- Location of respondents in relation to type of jobs***

# %%
#Plotting our bar graph 
df.groupby(['type_of_location','type_of_job']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Location of respondents in relation to type of jobs',fontsize=16)
plt.xlabel('Location',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=14)

# %% [markdown]
# Other than farming - larger arable lands in rural areas, The distribution of employment/ careers seem to be replicated in both urban and rural areas

# %% [markdown]
# ***m- Type of job in relation to respondents age***

# %%
df[df['year'] < 2020].sample(200).plot.scatter(y='type_of_job', x='respondent_age')

# %% [markdown]
# Majority of the younger population is employed in farming, fishing, informal sector or is self employed

# %% [markdown]
# ***n-Cellphone access correlation with access to bank account***

# %%
#Plotting our bar graph 
df.groupby(['cell_phone_access','has_a_bank_account']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Cellphone access correlation with to access to bank account',fontsize=16)
plt.xlabel('Access to mobile phones',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=14)

# %% [markdown]
# Majority of the population have access to mobile phones. Most people with bank accounts have phones. This is a very insightful graph. given the high penetration to access to mobile phones, disruptive technologies can be used to bank those with mobile phones( the majority) on their mobile phones

# %% [markdown]
# ***o- Cellphone access in relation to level of education***

# %%
#Plotting our bar graph 
df.groupby(['cell_phone_access','level_of_education']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Cellphone access in correlation to level of education',fontsize=16)
plt.xlabel('Access to mobile phones',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=14)

# %% [markdown]
# Most people have mobile phones despite their level of education

# %% [markdown]
# ***p- Cellphone access in relation to type of job***

# %%
#Plotting our bar graph 
df.groupby(['cell_phone_access','type_of_job']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Cellphone access correlated to type of job',fontsize=16)
plt.xlabel('Access to mobile phones',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=14)

# %% [markdown]
# Most people with no source of income don't have mobile phones - which is expected. However I believe there will be an upward trend to access of mobile phones.

# %% [markdown]
# ***q- Mobille phone access in relation to Location of respondents***

# %%
#Plotting our bar graph 
df.groupby(['cell_phone_access','type_of_location']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Cellphone access correlated to location of respondent',fontsize=16)
plt.xlabel('Access to mobile phones',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=14)

# %% [markdown]
# Most people in both urban and rural areas have mobile phones

# %% [markdown]
# ***r- Household size in relation to age***

# %%
df[df['year'] < 2020].sample(700).plot.scatter(y='household_size', x='respondent_age')

# %% [markdown]
# There are very few people with large households. The elderly population is also quite little as compared to the younger population

# %% [markdown]
# ***s- Household size in relation to Access to banking facilities***

# %%
#Plotting our bar graph 
df.groupby(['household_size','has_a_bank_account']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Access to bank facilities in correlation to Household size',fontsize=16)
plt.xlabel('Access to mobile phones',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=14)

# %% [markdown]
# Smaller households have more access to banking facilities

# %% [markdown]
# ***t- Relation of gender to the level of education***

# %%
#Plotting our bar graph 
df.groupby(['gender_of_respondent','level_of_education']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Gender related to level of education',fontsize=16)
plt.xlabel('Gender',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=14)

# %% [markdown]
# In this case, more females are educated than men

# %% [markdown]
# ***u- Gender in  correlation to type of job***

# %%
#Plotting our bar graph 
df.groupby(['gender_of_respondent','type_of_job']).year.count().unstack().plot(kind='bar',figsize=(12,8))

# labels and title
plt.title('Gender in relation to type of job',fontsize=16)
plt.xlabel('Gender',fontsize=14)
plt.ylabel('Number',fontsize=14)
plt.legend(fontsize=10)

# %% [markdown]
# There seems to be no co-relation between career choices between men and women

# %% [markdown]
# ## ***VII- Multivariate exploratory Analysis***

# %% [markdown]
# ***1-Multivariate charts***

# %% [markdown]
# ***a-Chi Tests***

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['country']=lb.fit_transform(df['country'].astype(str))
df['type_of_location']=lb.fit_transform(df['type_of_location'].astype(str))
df['cell_phone_access']=lb.fit_transform(df['cell_phone_access'].astype(str))
df['gender_of_respondent']=lb.fit_transform(df['gender_of_respondent'].astype(str))
df['marital_status']=lb.fit_transform(df['marital_status'].astype(str))
df['level_of_education']=lb.fit_transform(df['level_of_education'].astype(str))
df['type_of_job']=lb.fit_transform(df['type_of_job'].astype(str))

# %%
# Let's show 10 samples

df.sample(10)
# Out:
#        country  year has_a_bank_account  type_of_location  cell_phone_access  \
# 1038         0  2018                 No                 0                  0
# 2251         0  2018                 No                 0                  1
# 604          0  2018                Yes                 1                  1
# 20238        2  2017                 No                 1                  1
# 7646         1  2016                 No                 0                  1
# 8368         1  2016                 No                 0                  1
# 16019        2  2017                 No                 1                  0
# 7825         1  2016                 No                 0                  1
# 663          0  2018                 No                 1                  1
# 4795         0  2018                Yes                 1                  1
#
#        household_size  respondent_age  gender_of_respondent  marital_status  \
# ...

# %%
df['has_a_bank_account']=lb.fit_transform(df['has_a_bank_account'].astype(str))

# %% [markdown]
# ***b-Co-relation of data columns***

# %%
hsizeage = df[['has_a_bank_account', 'type_of_location',
       'cell_phone_access', 
       'gender_of_respondent','marital_status',
       'level_of_education', 'type_of_job']]
sns.heatmap(hsizeage.corr(),annot=False)
plt.show()

# %% [markdown]
# ## ***VIII- Implementing the Solution***

# %% [markdown]
# ***1-The findings***

# %%
df.columns
# Out:
# Index(['country', 'year', 'has_a_bank_account', 'type_of_location',
#        'cell_phone_access', 'household_size', 'respondent_age',
#        'gender_of_respondent', 'marital_status', 'level_of_education',
#        'type_of_job'],
#       dtype='object')

# %% [markdown]
# The data was skewed in the following ways:
#
#
# 1.  Majority of the data was collected in Rwanda
# 2.  Majority of the data was collected in Rural areas
# 3.  Majority of those who were interviewed were women
# 4.  Majority of those interviewed do not have bank accounts
# 5.   Majority of the population have mobile phones
# 6.   The size of households seem to be very big
# 7.   Respondent age was upto 83 years. There were several outliers of
# people older than that
# 8.  Most of the population that participated is married. followed closely by single/never married
# 9.  Most of the population has atleast primary school education
# 10.  Most of the population is involved in farming followed closely by self employment.

# %% [markdown]
# ## ***2- The Co - relations***

# %% [markdown]
# ***The strongest co-relations are***
#
# 1.   Type of location and job
# 2.   Access to banking and level of education
# 3.   Access to banking and cellphone access
# 4.   Cellphone access to level of education
#
#
# ***The weakest co-relations are***
# 1.  Access to banking and the type of job
# 2.  Access to banking and marital status
# 3.  Type of Location and cell-phone access
# 4.  Cellphone access and type of job
# 5.  Cellphone access and marital status
# 6.  Gender of respondent and marital status
# 7.  Marital status and level of education
# 8.  Gender of respondent and type of job

# %% [markdown]
# ***3-The Recomendations***
#
#
# 1.   Banks should leverage on the high penetration of mobile phones across the region to increase the banked population
# 2.   Education and knowledge about money and banking should be increased. Possibly in the primary school curriculum - This is the common place to reach most of the population
# 3.   Farmers, self employed people and people in the informal sector should also be targeted by future marketing campaigns
# 4.  There is a great potential for growth of the formal banking sector
# 5.   Interestingly, the uptake of formal banking is equal both in rural and urban areas despite more of the skew being towards the rural population. Shows that marketing campaigns should focus their attention to the rural population.

# %% [markdown]
# ***4- Challenging the solution***

# %% [markdown]
# Due to the data skews stated above, the data may not be an accurate representation of the real world

# %% [markdown]
# ***5-Follow up questions***

# %% [markdown]
# At this point, we can refine our question or collect new data, all in an iterative process to get  the truth.

# %% [markdown]
# ***6- Did we have the right data?***
#
# Yes we did. However not the best standards
#
# 1.  the data was skewed.
# 2.  If more parameters were captured we would be able to see more demographic influencers to banking in the region

# %% [markdown]
# ***7- Do we need other data to answer our question?***

# %% [markdown]
# No, but for a more descriptive analysis information in the list below should've been included:
#
# 1.   Population - to find out whether the age or gender distribution are an accurate representation
# 2.   Defined criteria of what the different careers involved and how they were put in bins
# 3.   Age -do we need information on banking access of 80+ year old people? - I believe there shouf be a cut off
# 4.   Household - Who constitutes of a house hold? Is it possible that one household was interviewed more than once - with different members participating

# %% [markdown]
# ***8-Did we have the right question?***
#
# Yes, The data was able to display the correlation of different demographic and socio - economic factors to the access of formal banking and how the banks can be able to leverage this and increase the percentage of population that is formally banked.
#
# However, the data had alot of information that I was able to gather. For example: It doesn't seem to be any gender disparities. Both Men and women have the same careers and the same levels of education.
